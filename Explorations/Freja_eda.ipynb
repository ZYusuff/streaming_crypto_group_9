# %%
from dotenv import load_dotenv
import os
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from pprint import pprint

load_dotenv()

API_KEY = os.getenv("COINMARKET_API")

url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"
parameters = {
    #'symbol': target_symbol,
    "limit": 20,  # You can adjust the limit to get more or fewer coins
    "convert": "USD",
}

headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": API_KEY,
}

session = Session()
session.headers.update(headers)

# Send a POST request to the server with the data
#response = requests.post(url, json=data_to_send)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)  # Get full JSON response
    pprint(data["data"])  # This prints only the data portion with all coin details
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# [{'circulating_supply': 19823115,
#   'cmc_rank': 1,
#   'date_added': '2010-07-13T00:00:00.000Z',
#   'id': 1,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 21000000,
#   'name': 'Bitcoin',
#   'num_market_pairs': 11937,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 2020093866841,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 1906883477770.658,
#                     'market_cap_dominance': 60.351,
#                     'percent_change_1h': 0.28580183,
#                     'percent_change_24h': -2.06645561,
#                     'percent_change_30d': 3.15546643,
#                     'percent_change_60d': -5.41071122,
#                     'percent_change_7d': -1.7028254,
#                     'percent_change_90d': 5.57076062,
#                     'price': 96194.9460400476,
#                     'tvl': None,
#                     'volume_24h': 36473573605.10254,
#                     'volume_change_24h': 6.6481}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'bitcoin',
#   'symbol': 'BTC',
#   'tags': ['mineable',
#            'pow',
#            'sha-256',
#            'store-of-value',
#            'state-channel',
#            'coinbase-ventures-portfolio',
#            'three-arrows-capital-portfolio',
#            'polychain-capital-portfolio',
#            'binance-labs-portfolio',
#            'blockchain-capital-portfolio',
#            'boostvc-portfolio',
#            'cms-holdings-portfolio',
#            'dcg-portfolio',
#            'dragonfly-capital-portfolio',
#            'electric-capital-portfolio',
#            'fabric-ventures-portfolio',
#            'framework-ventures-portfolio',
#            'galaxy-digital-portfolio',
#            'huobi-capital-portfolio',
#            'alameda-research-portfolio',
#            'a16z-portfolio',
#            '1confirmation-portfolio',
#            'winklevoss-capital-portfolio',
#            'usv-portfolio',
#            'placeholder-ventures-portfolio',
#            'pantera-capital-portfolio',
#            'multicoin-capital-portfolio',
#            'paradigm-portfolio',
#            'bitcoin-ecosystem',
#            'ftx-bankruptcy-estate',
#            '2017-2018-alt-season'],
#   'total_supply': 19823115,
#   'tvl_ratio': None},
#  {'circulating_supply': 120543070.67367822,
#   'cmc_rank': 2,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'id': 1027,
#   'infinite_supply': True,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'Ethereum',
#   'num_market_pairs': 9926,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 317382947276.33,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 317382947276.331,
#                     'market_cap_dominance': 10.0449,
#                     'percent_change_1h': 0.95407881,
#                     'percent_change_24h': -2.86681004,
#                     'percent_change_30d': -17.39669191,
#                     'percent_change_60d': -32.83738762,
#                     'percent_change_7d': -4.82494707,
#                     'percent_change_90d': -18.1929988,
#                     'price': 2632.9422794904353,
#                     'tvl': None,
#                     'volume_24h': 19512779022.371098,
#                     'volume_change_24h': 9.0077}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'ethereum',
#   'symbol': 'ETH',
#   'tags': ['pos',
#            'smart-contracts',
#            'ethereum-ecosystem',
#            'coinbase-ventures-portfolio',
#            'three-arrows-capital-portfolio',
#            'polychain-capital-portfolio',
#            'heco-ecosystem',
#            'binance-labs-portfolio',
#            'solana-ecosystem',
#            'blockchain-capital-portfolio',
#            'boostvc-portfolio',
#            'cms-holdings-portfolio',
#            'dcg-portfolio',
#            'dragonfly-capital-portfolio',
#            'electric-capital-portfolio',
#            'fabric-ventures-portfolio',
#            'framework-ventures-portfolio',
#            'hashkey-capital-portfolio',
#            'kenetic-capital-portfolio',
#            'huobi-capital-portfolio',
#            'alameda-research-portfolio',
#            'a16z-portfolio',
#            '1confirmation-portfolio',
#            'winklevoss-capital-portfolio',
#            'usv-portfolio',
#            'placeholder-ventures-portfolio',
#            'pantera-capital-portfolio',
#            'multicoin-capital-portfolio',
#            'paradigm-portfolio',
#            'tezos-ecosystem',
#            'near-protocol-ecosystem',
#            'velas-ecosystem',
#            'ethereum-pow-ecosystem',
#            'osmosis-ecosystem',
#            'layer-1',
#            'ftx-bankruptcy-estate',
#            'zksync-era-ecosystem',
#            'viction-ecosystem',
#            'klaytn-ecosystem',
#            'sora-ecosystem',
#            'rsk-rbtc-ecosystem',
#            'starknet-ecosystem'],
#   'total_supply': 120543070.67367822,
#   'tvl_ratio': None},
#  {'circulating_supply': 141953250507.84326,
#   'cmc_rank': 3,
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'id': 825,
#   'infinite_supply': True,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'Tether USDt',
#   'num_market_pairs': 116284,
#   'platform': {'id': 1027,
#                'name': 'Ethereum',
#                'slug': 'ethereum',
#                'symbol': 'ETH',
#                'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#   'quote': {'USD': {'fully_diluted_market_cap': 143588529709.78,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 141971009128.6054,
#                     'market_cap_dominance': 4.4925,
#                     'percent_change_1h': 0.03535052,
#                     'percent_change_24h': -0.00461987,
#                     'percent_change_30d': 0.08522314,
#                     'percent_change_60d': 0.01224933,
#                     'percent_change_7d': 0.01050009,
#                     'percent_change_90d': -0.02181808,
#                     'price': 1.0001251018958608,
#                     'tvl': None,
#                     'volume_24h': 80116163795.62762,
#                     'volume_change_24h': 4.2595}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'tether',
#   'symbol': 'USDT',
#   'tags': ['stablecoin',
#            'asset-backed-stablecoin',
#            'ethereum-ecosystem',
#            'waves-ecosystem',
#            'bitcoin-cash-ecosystem',
#            'heco-ecosystem',
#            'algorand-ecosystem',
#            'avalanche-ecosystem',
#            'solana-ecosystem',
#            'polygon-ecosystem',
#            'fantom-ecosystem',
#            'tezos-ecosystem',
#            'near-protocol-ecosystem',
#            'arbitrum-ecosystem',
#            'celo-ecosystem',
#            'iotex-ecosystem',
#            'zilliqa-ecosystem',
#            'harmony-ecosystem',
#            'moonriver-ecosystem',
#            'injective-ecosystem',
#            'bnb-chain-ecosystem',
#            'oasis-ecosystem',
#            'moonbeam-ecosystem',
#            'usd-stablecoin',
#            'xdc-ecosystem',
#            'everscale-ecosystem',
#            'velas-ecosystem',
#            'ethereum-pow-ecosystem',
#            'aptos-ecosystem',
#            'sui-ecosystem',
#            'optimism-ecosystem',
#            'canto-ecosystem',
#            'osmosis-ecosystem',
#            'zksync-era-ecosystem',
#            'pulsechain-ecosystem',
#            'sei-ecosystem',
#            'toncoin-ecosystem',
#            'fiat-stablecoin',
#            'viction-ecosystem',
#            'gnosis-chain-ecosystem',
#            'klaytn-ecosystem',
#            'okexchain-ecosystem',
#            'conflux-ecosystem',
#            'kcc-ecosystem',
#            'tron20-ecosystem',
#            'kardiachain-ecosystem',
#            'rsk-rbtc-ecosystem',
#            'telos-ecosystem',
#            'boba-network-ecosystem',
#            'fusion-network-ecosystem',
#            'hoo-smart-chain-ecosystem',
#            'secret-ecosystem',
#            'aurora-ecosystem',
#            'metis-andromeda-ecosystem',
#            'meter-ecosystem',
#            'fuse-ecosystem',
#            'syscoin-ecosystem',
#            'milkomeda-ecosystem',
#            'bitgert-ecosystem',
#            'astar-ecosystem',
#            'cube-network-ecosystem',
#            'thundercore-ecosystem',
#            'redlight-chain-ecosystem',
#            'core-ecosystem',
#            'polygon-zkevm-ecosystem',
#            'eos-evm-ecosystem',
#            'starknet-ecosystem',
#            'mantle-ecosystem',
#            'neon-evm-ecosystem',
#            'manta-pacific-ecosystem',
#            'scroll-ecosystem',
#            'x-layer-ecosystem'],
#   'total_supply': 143570568759.4433,
#   'tvl_ratio': None},
#  {'circulating_supply': 57762545657,
#   'cmc_rank': 4,
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'id': 52,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 100000000000,
#   'name': 'XRP',
#   'num_market_pairs': 1528,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 241639088088.93,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 139576888582.52414,
#                     'market_cap_dominance': 4.4174,
#                     'percent_change_1h': 0.5695841,
#                     'percent_change_24h': -3.358967,
#                     'percent_change_30d': -0.65585423,
#                     'percent_change_60d': -2.66699349,
#                     'percent_change_7d': -3.96312917,
#                     'percent_change_90d': 245.03214103,
#                     'price': 2.4163908808892565,
#                     'tvl': None,
#                     'volume_24h': 4661254322.248312,
#                     'volume_change_24h': 4.4254}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'xrp',
#   'symbol': 'XRP',
#   'tags': ['medium-of-exchange',
#            'enterprise-solutions',
#            'xrp-ecosystem',
#            'arrington-xrp-capital-portfolio',
#            'galaxy-digital-portfolio',
#            'a16z-portfolio',
#            'pantera-capital-portfolio',
#            'ftx-bankruptcy-estate',
#            '2017-2018-alt-season',
#            'klaytn-ecosystem',
#            'made-in-america'],
#   'total_supply': 99986504676,
#   'tvl_ratio': None},
#  {'circulating_supply': 488184520.2151873,
#   'cmc_rank': 5,
#   'date_added': '2020-04-10T00:00:00.000Z',
#   'id': 5426,
#   'infinite_supply': True,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'Solana',
#   'num_market_pairs': 840,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 116463378431.3,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 95728414793.65482,
#                     'market_cap_dominance': 3.0296,
#                     'percent_change_1h': 0.68988534,
#                     'percent_change_24h': -4.30775355,
#                     'percent_change_30d': 8.07750219,
#                     'percent_change_60d': -13.17734564,
#                     'percent_change_7d': -4.57329135,
#                     'percent_change_90d': -10.37715855,
#                     'price': 196.09063956280013,
#                     'tvl': None,
#                     'volume_24h': 3210944128.612941,
#                     'volume_change_24h': -18.8451}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'solana',
#   'symbol': 'SOL',
#   'tags': ['pos',
#            'platform',
#            'solana-ecosystem',
#            'cms-holdings-portfolio',
#            'kenetic-capital-portfolio',
#            'alameda-research-portfolio',
#            'multicoin-capital-portfolio',
#            'okx-ventures-portfolio',
#            'layer-1',
#            'ftx-bankruptcy-estate',
#            'alleged-sec-securities',
#            'cmc-crypto-awards-2024',
#            'made-in-america'],
#   'total_supply': 593926251.099815,
#   'tvl_ratio': None},
#  {'circulating_supply': 142479396.42000002,
#   'cmc_rank': 6,
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'id': 1839,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'BNB',
#   'num_market_pairs': 2355,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 90958990509.1,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 90958990509.10114,
#                     'market_cap_dominance': 2.8787,
#                     'percent_change_1h': 0.68801026,
#                     'percent_change_24h': -0.2744211,
#                     'percent_change_30d': -6.02466469,
#                     'percent_change_60d': -12.29250105,
#                     'percent_change_7d': 11.19744293,
#                     'percent_change_90d': -2.04578534,
#                     'price': 638.4010095113872,
#                     'tvl': None,
#                     'volume_24h': 1982141874.5744634,
#                     'volume_change_24h': 1.1221}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'bnb',
#   'symbol': 'BNB',
#   'tags': ['marketplace',
#            'centralized-exchange',
#            'payments',
#            'smart-contracts',
#            'ethereum-ecosystem',
#            'alameda-research-portfolio',
#            'multicoin-capital-portfolio',
#            'bnb-chain-ecosystem',
#            'layer-1',
#            'alleged-sec-securities',
#            'celsius-bankruptcy-estate'],
#   'total_supply': 142479396.42000002,
#   'tvl_ratio': None},
#  {'circulating_supply': 56047576765.48343,
#   'cmc_rank': 7,
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'id': 3408,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'USDC',
#   'num_market_pairs': 25631,
#   'platform': {'id': 1027,
#                'name': 'Ethereum',
#                'slug': 'ethereum',
#                'symbol': 'ETH',
#                'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'quote': {'USD': {'fully_diluted_market_cap': 56059142855.99,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 56059142855.98735,
#                     'market_cap_dominance': 1.7742,
#                     'percent_change_1h': 0.02375917,
#                     'percent_change_24h': 0.02227837,
#                     'percent_change_30d': 0.02548439,
#                     'percent_change_60d': 0.02889841,
#                     'percent_change_7d': 0.046163,
#                     'percent_change_90d': 0.05291859,
#                     'price': 1.0002063620083401,
#                     'tvl': None,
#                     'volume_24h': 7053774407.727184,
#                     'volume_change_24h': 5.4253}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'usd-coin',
#   'symbol': 'USDC',
#   'tags': ['medium-of-exchange',
#            'stablecoin',
#            'asset-backed-stablecoin',
#            'ethereum-ecosystem',
#            'waves-ecosystem',
#            'bitcoin-cash-ecosystem',
#            'wanchain-ecosystem',
#            'coinbase-ventures-portfolio',
#            'algorand-ecosystem',
#            'solana-ecosystem',
#            'hedera-hashgraph-ecosystem',
#            'polygon-ecosystem',
#            'near-protocol-ecosystem',
#            'arbitrum-ecosystem',
#            'celo-ecosystem',
#            'iotex-ecosystem',
#            'harmony-ecosystem',
#            'moonriver-ecosystem',
#            'injective-ecosystem',
#            'bnb-chain-ecosystem',
#            'oasis-ecosystem',
#            'moonbeam-ecosystem',
#            'usd-stablecoin',
#            'everscale-ecosystem',
#            'velas-ecosystem',
#            'ethereum-pow-ecosystem',
#            'aptos-ecosystem',
#            'sui-ecosystem',
#            'optimism-ecosystem',
#            'canto-ecosystem',
#            'osmosis-ecosystem',
#            'zksync-era-ecosystem',
#            'pulsechain-ecosystem',
#            'base-ecosystem',
#            'sei-ecosystem',
#            'multiversx-ecosystem',
#            'fiat-stablecoin',
#            'viction-ecosystem',
#            'gnosis-chain-ecosystem',
#            'okexchain-ecosystem',
#            'conflux-ecosystem',
#            'kcc-ecosystem',
#            'tron20-ecosystem',
#            'kardiachain-ecosystem',
#            'telos-ecosystem',
#            'ronin-ecosystem',
#            'boba-network-ecosystem',
#            'kava-ecosystem',
#            'secret-ecosystem',
#            'aurora-ecosystem',
#            'metis-andromeda-ecosystem',
#            'meter-ecosystem',
#            'fuse-ecosystem',
#            'elastos-ecosystem',
#            'syscoin-ecosystem',
#            'milkomeda-ecosystem',
#            'evmos-ecosystem',
#            'bitgert-ecosystem',
#            'astar-ecosystem',
#            'thundercore-ecosystem',
#            'tomb-chain-ecosystem',
#            'wemix-ecosystem',
#            'sx-network-ecosystem',
#            'godwoken-ecosystem',
#            'energi-ecosystem',
#            'core-ecosystem',
#            'polygon-zkevm-ecosystem',
#            'starknet-ecosystem',
#            'mantle-ecosystem',
#            'neon-evm-ecosystem',
#            'scroll-ecosystem',
#            'shido-network-ecosystem',
#            'made-in-america'],
#   'total_supply': 56047576765.48343,
#   'tvl_ratio': None},
#  {'circulating_supply': 148012156383.70526,
#   'cmc_rank': 8,
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'id': 74,
#   'infinite_supply': True,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'num_market_pairs': 1163,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 37697456349.53,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 37697456349.52617,
#                     'market_cap_dominance': 1.1929,
#                     'percent_change_1h': 0.92059566,
#                     'percent_change_24h': -4.31604542,
#                     'percent_change_30d': -22.01133643,
#                     'percent_change_60d': -37.83702554,
#                     'percent_change_7d': -4.13453597,
#                     'percent_change_90d': -36.19464099,
#                     'price': 0.2546916231110075,
#                     'tvl': None,
#                     'volume_24h': 1458426274.2309964,
#                     'volume_change_24h': 4.0299}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'dogecoin',
#   'symbol': 'DOGE',
#   'tags': ['mineable',
#            'pow',
#            'scrypt',
#            'medium-of-exchange',
#            'memes',
#            'payments',
#            'doggone-doggerel',
#            'bnb-chain-ecosystem',
#            'ftx-bankruptcy-estate',
#            'made-in-america'],
#   'total_supply': 148012156383.70526,
#   'tvl_ratio': None},
#  {'circulating_supply': 35197202831.96437,
#   'cmc_rank': 9,
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'id': 2010,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 45000000000,
#   'name': 'Cardano',
#   'num_market_pairs': 1460,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 34770879107.92,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 27196392991.271072,
#                     'market_cap_dominance': 0.8607,
#                     'percent_change_1h': 1.37771553,
#                     'percent_change_24h': -4.83024048,
#                     'percent_change_30d': -16.95927055,
#                     'percent_change_60d': -30.81749953,
#                     'percent_change_7d': 2.75636977,
#                     'percent_change_90d': 32.89914982,
#                     'price': 0.7726862023982384,
#                     'tvl': None,
#                     'volume_24h': 1371615487.2786367,
#                     'volume_change_24h': 12.8235}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'cardano',
#   'symbol': 'ADA',
#   'tags': ['dpos',
#            'pos',
#            'platform',
#            'research',
#            'smart-contracts',
#            'staking',
#            'cardano-ecosystem',
#            'cardano',
#            'layer-1',
#            'alleged-sec-securities',
#            '2017-2018-alt-season',
#            'made-in-america'],
#   'total_supply': 44995082706.687096,
#   'tvl_ratio': None},
#  {'circulating_supply': 86102775614.31029,
#   'cmc_rank': 10,
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'id': 1958,
#   'infinite_supply': True,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'TRON',
#   'num_market_pairs': 1118,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 20735356118.21,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 20735349620.7098,
#                     'market_cap_dominance': 0.6563,
#                     'percent_change_1h': 1.01013111,
#                     'percent_change_24h': -2.50099735,
#                     'percent_change_30d': 6.90697872,
#                     'percent_change_60d': -18.16704868,
#                     'percent_change_7d': 6.76865458,
#                     'percent_change_90d': 33.02734261,
#                     'price': 0.24082091979928677,
#                     'tvl': None,
#                     'volume_24h': 558767837.2586004,
#                     'volume_change_24h': -13.9768}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'tron',
#   'symbol': 'TRX',
#   'tags': ['media',
#            'payments',
#            'ethereum-ecosystem',
#            'tron-ecosystem',
#            'layer-1',
#            'dwf-labs-portfolio',
#            'alleged-sec-securities',
#            '2017-2018-alt-season',
#            'tron20-ecosystem'],
#   'total_supply': 86102802594.92746,
#   'tvl_ratio': None},
#  {'circulating_supply': 638099970.4527867,
#   'cmc_rank': 11,
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'id': 1975,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'Chainlink',
#   'num_market_pairs': 1926,
#   'platform': {'id': 1027,
#                'name': 'Ethereum',
#                'slug': 'ethereum',
#                'symbol': 'ETH',
#                'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#   'quote': {'USD': {'fully_diluted_market_cap': 18717068830.27,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 11943361067.560148,
#                     'market_cap_dominance': 0.378,
#                     'percent_change_1h': 0.89855437,
#                     'percent_change_24h': -4.40208574,
#                     'percent_change_30d': -0.96077667,
#                     'percent_change_60d': -36.32635193,
#                     'percent_change_7d': -4.99534336,
#                     'percent_change_90d': 37.39315889,
#                     'price': 18.71706883027327,
#                     'tvl': None,
#                     'volume_24h': 420882414.0733669,
#                     'volume_change_24h': -2.6227}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'chainlink',
#   'symbol': 'LINK',
#   'tags': ['platform',
#            'defi',
#            'oracles',
#            'smart-contracts',
#            'ethereum-ecosystem',
#            'substrate',
#            'polkadot',
#            'heco-ecosystem',
#            'avalanche-ecosystem',
#            'solana-ecosystem',
#            'framework-ventures-portfolio',
#            'polygon-ecosystem',
#            'fantom-ecosystem',
#            'cardano-ecosystem',
#            'web3',
#            'near-protocol-ecosystem',
#            'arbitrum-ecosystem',
#            'cardano',
#            'injective-ecosystem',
#            'optimism-ecosystem',
#            'real-world-assets',
#            'celsius-bankruptcy-estate',
#            'gnosis-chain-ecosystem',
#            'sora-ecosystem',
#            'hoo-smart-chain-ecosystem',
#            'milkomeda-ecosystem',
#            'energi-ecosystem',
#            'made-in-america'],
#   'total_supply': 1000000000,
#   'tvl_ratio': None},
#  {'circulating_supply': 411906862.785265,
#   'cmc_rank': 12,
#   'date_added': '2020-07-13T00:00:00.000Z',
#   'id': 5805,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 715748719,
#   'name': 'Avalanche',
#   'num_market_pairs': 860,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 18076519397.46,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 10402872121.77858,
#                     'market_cap_dominance': 0.3292,
#                     'percent_change_1h': 0.78239467,
#                     'percent_change_24h': -5.82141895,
#                     'percent_change_30d': -27.29347517,
#                     'percent_change_60d': -52.02151784,
#                     'percent_change_7d': -6.06086944,
#                     'percent_change_90d': -24.98600845,
#                     'price': 25.25539888176565,
#                     'tvl': None,
#                     'volume_24h': 335579811.8608683,
#                     'volume_change_24h': 6.4396}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'avalanche',
#   'symbol': 'AVAX',
#   'tags': ['defi',
#            'smart-contracts',
#            'three-arrows-capital-portfolio',
#            'polychain-capital-portfolio',
#            'avalanche-ecosystem',
#            'cms-holdings-portfolio',
#            'dragonfly-capital-portfolio',
#            'moonbeam-ecosystem',
#            'real-world-assets',
#            'layer-1',
#            'zksync-era-ecosystem',
#            'klaytn-ecosystem',
#            'made-in-america'],
#   'total_supply': 450243162.785265,
#   'tvl_ratio': None},
#  {'circulating_supply': 3089707194.508888,
#   'cmc_rank': 13,
#   'date_added': '2022-07-12T08:03:11.000Z',
#   'id': 20947,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 10000000000,
#   'name': 'Sui',
#   'num_market_pairs': 554,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 32892134227.67,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 10162706376.59956,
#                     'market_cap_dominance': 0.3216,
#                     'percent_change_1h': 1.12537171,
#                     'percent_change_24h': -6.00770808,
#                     'percent_change_30d': -26.82047083,
#                     'percent_change_60d': -30.2705485,
#                     'percent_change_7d': -8.47118422,
#                     'percent_change_90d': -2.77746855,
#                     'price': 3.289213422767374,
#                     'tvl': None,
#                     'volume_24h': 1254996282.2267435,
#                     'volume_change_24h': -5.2324}},
#   'self_reported_circulating_supply': 3089707194.508888,
#   'self_reported_market_cap': 10162706376.59956,
#   'slug': 'sui',
#   'symbol': 'SUI',
#   'tags': ['binance-launchpool',
#            'coinbase-ventures-portfolio',
#            'binance-labs-portfolio',
#            'electric-capital-portfolio',
#            'a16z-portfolio',
#            'sui-ecosystem',
#            'layer-1',
#            'move-vm',
#            'cmc-crypto-yearbook-2024-2025',
#            'made-in-america'],
#   'total_supply': 10000000000,
#   'tvl_ratio': None},
#  {'circulating_supply': 30592511893.585205,
#   'cmc_rank': 14,
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'id': 512,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 50001806812,
#   'name': 'Stellar',
#   'num_market_pairs': 672,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 15896406334.69,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 9725868540.865313,
#                     'market_cap_dominance': 0.3078,
#                     'percent_change_1h': 1.12896032,
#                     'percent_change_24h': -5.15713267,
#                     'percent_change_30d': -21.94008657,
#                     'percent_change_60d': -27.82031743,
#                     'percent_change_7d': -7.05668587,
#                     'percent_change_90d': 152.62239795,
#                     'price': 0.317916638381848,
#                     'tvl': None,
#                     'volume_24h': 350358019.3457437,
#                     'volume_change_24h': 0.1092}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'stellar',
#   'symbol': 'XLM',
#   'tags': ['medium-of-exchange',
#            'enterprise-solutions',
#            'decentralized-exchange-dex-token',
#            'smart-contracts',
#            'hashkey-capital-portfolio',
#            '2017-2018-alt-season',
#            'made-in-america'],
#   'total_supply': 50001786894.45019,
#   'tvl_ratio': None},
#  {'circulating_supply': 2494071978.951122,
#   'cmc_rank': 15,
#   'date_added': '2021-08-26T13:40:22.000Z',
#   'id': 11419,
#   'infinite_supply': True,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'Toncoin',
#   'num_market_pairs': 673,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 19169427103.66,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 9334030174.620588,
#                     'market_cap_dominance': 0.2954,
#                     'percent_change_1h': 0.70368476,
#                     'percent_change_24h': -3.36784899,
#                     'percent_change_30d': -27.25804251,
#                     'percent_change_60d': -40.97831323,
#                     'percent_change_7d': -1.84617042,
#                     'percent_change_90d': -31.34620781,
#                     'price': 3.742486284836896,
#                     'tvl': None,
#                     'volume_24h': 120883942.46522216,
#                     'volume_change_24h': 10.3307}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'toncoin',
#   'symbol': 'TON',
#   'tags': ['pos',
#            'ethereum-ecosystem',
#            'layer-1',
#            'ftx-bankruptcy-estate',
#            'dwf-labs-portfolio',
#            'toncoin-ecosystem',
#            'cmc-crypto-yearbook-2024-2025'],
#   'total_supply': 5122110181.493914,
#   'tvl_ratio': None},
#  {'circulating_supply': 589253898756133.4,
#   'cmc_rank': 16,
#   'date_added': '2020-08-01T00:00:00.000Z',
#   'id': 5994,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'Shiba Inu',
#   'num_market_pairs': 932,
#   'platform': {'id': 1027,
#                'name': 'Ethereum',
#                'slug': 'ethereum',
#                'symbol': 'ETH',
#                'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   'quote': {'USD': {'fully_diluted_market_cap': 9313230991.22,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 9309228293.18918,
#                     'market_cap_dominance': 0.2946,
#                     'percent_change_1h': 1.08939507,
#                     'percent_change_24h': -3.39709711,
#                     'percent_change_30d': -23.88611357,
#                     'percent_change_60d': -44.5289829,
#                     'percent_change_7d': -3.170533,
#                     'percent_change_90d': -39.014366,
#                     'price': 1.579833126745567e-05,
#                     'tvl': None,
#                     'volume_24h': 253623610.85885927,
#                     'volume_change_24h': 9.3009}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'shiba-inu',
#   'symbol': 'SHIB',
#   'tags': ['memes', 'ethereum-ecosystem', 'doggone-doggerel', 'base-ecosystem'],
#   'total_supply': 589507260833701.4,
#   'tvl_ratio': None},
#  {'circulating_supply': 924139765.9,
#   'cmc_rank': 17,
#   'date_added': '2019-05-21T00:00:00.000Z',
#   'id': 3957,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': None,
#   'name': 'UNUS SED LEO',
#   'num_market_pairs': 57,
#   'platform': {'id': 1027,
#                'name': 'Ethereum',
#                'slug': 'ethereum',
#                'symbol': 'ETH',
#                'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#   'quote': {'USD': {'fully_diluted_market_cap': 9698341078.75,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 9096897371.399044,
#                     'market_cap_dominance': 0.2879,
#                     'percent_change_1h': 0.34827934,
#                     'percent_change_24h': -0.27013285,
#                     'percent_change_30d': 6.46942021,
#                     'percent_change_60d': 4.37671846,
#                     'percent_change_7d': 0.52112785,
#                     'percent_change_90d': 28.02597192,
#                     'price': 9.843638058946388,
#                     'tvl': None,
#                     'volume_24h': 716510.79009795,
#                     'volume_change_24h': 49.6495}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'unus-sed-leo',
#   'symbol': 'LEO',
#   'tags': ['marketplace',
#            'centralized-exchange',
#            'discount-token',
#            'payments',
#            'ethereum-ecosystem',
#            'kenetic-capital-portfolio',
#            'alameda-research-portfolio'],
#   'total_supply': 985239504,
#   'tvl_ratio': None},
#  {'circulating_supply': 75523799.5540892,
#   'cmc_rank': 18,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'id': 2,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 84000000,
#   'name': 'Litecoin',
#   'num_market_pairs': 1314,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 9911035113.1,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 8910940824.465971,
#                     'market_cap_dominance': 0.282,
#                     'percent_change_1h': 1.18662582,
#                     'percent_change_24h': -9.43480471,
#                     'percent_change_30d': 20.15800556,
#                     'percent_change_60d': -4.05118772,
#                     'percent_change_7d': 14.88713005,
#                     'percent_change_90d': 43.55828966,
#                     'price': 117.98851325116483,
#                     'tvl': None,
#                     'volume_24h': 1453888407.7796474,
#                     'volume_change_24h': -23.1792}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'litecoin',
#   'symbol': 'LTC',
#   'tags': ['mineable',
#            'pow',
#            'scrypt',
#            'medium-of-exchange',
#            'heco-ecosystem',
#            '2017-2018-alt-season',
#            'hoo-smart-chain-ecosystem',
#            'made-in-america'],
#   'total_supply': 84000000,
#   'tvl_ratio': None},
#  {'circulating_supply': 38267523224.99082,
#   'cmc_rank': 19,
#   'date_added': '2019-09-17T00:00:00.000Z',
#   'id': 4642,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 50000000000,
#   'name': 'Hedera',
#   'num_market_pairs': 316,
#   'platform': None,
#   'quote': {'USD': {'fully_diluted_market_cap': 11257611700.6,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 8616018344.210674,
#                     'market_cap_dominance': 0.2726,
#                     'percent_change_1h': 0.77123298,
#                     'percent_change_24h': -7.26459319,
#                     'percent_change_30d': -15.79142636,
#                     'percent_change_60d': -26.15830593,
#                     'percent_change_7d': -10.99181501,
#                     'percent_change_90d': 268.51623218,
#                     'price': 0.22515223401194503,
#                     'tvl': None,
#                     'volume_24h': 276136387.410657,
#                     'volume_change_24h': -5.2246}},
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'slug': 'hedera',
#   'symbol': 'HBAR',
#   'tags': ['dag',
#            'marketplace',
#            'enterprise-solutions',
#            'defi',
#            'payments',
#            'dcg-portfolio',
#            'hedera-hashgraph-ecosystem',
#            'real-world-assets',
#            'layer-1',
#            'made-in-america'],
#   'total_supply': 50000000000,
#   'tvl_ratio': None},
#  {'circulating_supply': 333928180,
#   'cmc_rank': 20,
#   'date_added': '2024-07-15T10:14:50.000Z',
#   'id': 32196,
#   'infinite_supply': False,
#   'last_updated': '2025-02-12T08:19:00.000Z',
#   'max_supply': 1000000000,
#   'name': 'Hyperliquid',
#   'num_market_pairs': 51,
#   'platform': {'id': 32196,
#                'name': 'Hyperliquid',
#                'slug': 'hyperliquid',
#                'symbol': 'HYPE',
#                'token_address': '0x0d01dc56dcaaca66ad901c959b4011ec'},
#   'quote': {'USD': {'fully_diluted_market_cap': 23816301479.58,
#                     'last_updated': '2025-02-12T08:19:00.000Z',
#                     'market_cap': 7952934207.407074,
#                     'market_cap_dominance': 0.2517,
#                     'percent_change_1h': 1.0258374,
#                     'percent_change_24h': -3.08885841,
#                     'percent_change_30d': 18.7928557,
#                     'percent_change_60d': 12.00426201,
#                     'percent_change_7d': -10.81255625,
#                     'percent_change_90d': 644.19512439,
#                     'price': 23.816301479578854,
#                     'tvl': None,
#                     'volume_24h': 111153934.67832924,
#                     'volume_change_24h': 0.5378}},
#   'self_reported_circulating_supply': 333931719,
#   'self_reported_market_cap': 7953018493.29801,
#   'slug': 'hyperliquid',
#   'symbol': 'HYPE',
#   'tags': ['decentralized-exchange-dex-token',
#            'derivatives',
#            'layer-1',
#            'hyperliquid-ecosystem'],
#   'total_supply': 999993930,
#   'tvl_ratio': None}]

# %% [markdown]
# ### All keys

# %%
titles = data["data"][0].keys()
pprint(titles)
# Out:
# dict_keys(['id', 'name', 'symbol', 'slug', 'num_market_pairs', 'date_added', 'tags', 'max_supply', 'circulating_supply', 'total_supply', 'infinite_supply', 'platform', 'cmc_rank', 'self_reported_circulating_supply', 'self_reported_market_cap', 'tvl_ratio', 'last_updated', 'quote'])

# %% [markdown]
# ### All crypto

# %%
crypto = [item['name'] for item in data['data']]
pprint(crypto)
# Out:
# ['Bitcoin',
#  'Ethereum',
#  'Tether USDt',
#  'XRP',
#  'Solana',
#  'BNB',
#  'USDC',
#  'Dogecoin',
#  'Cardano',
#  'TRON',
#  'Chainlink',
#  'Avalanche',
#  'Sui',
#  'Stellar',
#  'Toncoin',
#  'Shiba Inu',
#  'Litecoin',
#  'UNUS SED LEO',
#  'Hedera',
#  'Hyperliquid']

# %% [markdown]
# ### Shows all symbols

# %%
crypto = [item['symbol'] for item in data['data']]
pprint(crypto)
# Out:
# ['BTC',
#  'ETH',
#  'USDT',
#  'XRP',
#  'SOL',
#  'BNB',
#  'USDC',
#  'DOGE',
#  'ADA',
#  'TRX',
#  'LINK',
#  'AVAX',
#  'SUI',
#  'XLM',
#  'TON',
#  'SHIB',
#  'LTC',
#  'LEO',
#  'HBAR',
#  'HYPE']

# %% [markdown]
# ### Spec a crypto

# %%
target_symbol = "SHIB"
crypto_data = next(item for item in data['data'] if item['symbol'] == target_symbol)
print(json.dumps(crypto_data, indent=0))
# Out:
# {
# "id": 5994,
# "name": "Shiba Inu",
# "symbol": "SHIB",
# "slug": "shiba-inu",
# "num_market_pairs": 932,
# "date_added": "2020-08-01T00:00:00.000Z",
# "tags": [
# "memes",
# "ethereum-ecosystem",
# "doggone-doggerel",
# "base-ecosystem"
# ],
# "max_supply": null,
# "circulating_supply": 589253900860076.2,
# "total_supply": 589507260911478.4,
# "platform": {
# "id": 1027,
# "name": "Ethereum",
# "symbol": "ETH",
# "slug": "ethereum",
# "token_address": "0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce"
# },
# "infinite_supply": false,
# "cmc_rank": 16,
# "self_reported_circulating_supply": null,
# "self_reported_market_cap": null,
# "tvl_ratio": null,
# "last_updated": "2025-02-11T23:00:00.000Z",
# "quote": {
# "USD": {
# "price": 1.5637106790311823e-05,
# "volume_24h": 287405197.2117599,
# "volume_change_24h": 28.4617,
# "percent_change_1h": -0.69875008,
# "percent_change_24h": -0.88423365,
# "percent_change_7d": 0.19871458,
# "percent_change_30d": -26.80889711,
# "percent_change_60d": -44.55089201,
# "percent_change_90d": -38.50197941,
# "market_cap": 9214226174.356829,
# "market_cap_dominance": 0.2924,
# "fully_diluted_market_cap": 9218187992.54,
# "tvl": null,
# "last_updated": "2025-02-11T23:00:00.000Z"
# }
# }
# }
